# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
import pandas as pd
import numpy as np

# %%
#Работа с файлами
import os
import pathlib
from pathlib import Path

# %%
import string

# %%
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# import nltk
import re
# import string

# %%
dir = os.getcwd()
paths = sorted(Path('Data/1_4_class/').glob('*.txt'))
#paths[1]
#FileTXT = open(dir+'\\'+'Красная шапочка.txt',mode = 'r',encoding = 'utf-8')
# dir
# Text
FileTXT = open(paths[1],mode = 'r',encoding = 'utf-8')
text = FileTXT.read()

FileTXT.close()

# %%
Text = FileTXT.read()
Text
# Out:
# '\n\n\nЖила-была маленькая девочка. Мать любила ее без памяти, а бабушка еще больше. Ко дню рождения внучки подарила ей бабушка красную шапочку. С тех пор девочка всюду в ней ходила. Соседи так про нее и говорили:\n— Вот Красная Шапочка идет!\nКак-то раз испекла мама пирожок и сказала дочке:\n— Сходи-ка, Красная Шапочка, к бабушке, снеси ей пирожок и горшочек масла да узнай, здорова ли она.\nСобралась Красная Шапочка и пошла к бабушке.\nИдет она лесом, а навстречу ей — серый Волк.\n— Куда ты идешь, Красная Шапочка? — спрашивает Волк.\n— Иду к бабушке и несу ей пирожок и горшочек масла.\n— А далеко живет твоя бабушка?\n— Далеко, — отвечает Красная Шапочка. — Вон в той деревне, за мельницей, в первом домике с края.\n— Ладно, — говорит Волк, — я тоже хочу проведать твою бабушку. Я по этой дороге пойду, а ты ступай по той. Посмотрим, кто из нас раньше придет.\nСказал это Волк и побежал, что было духу, по самой короткой дорожке.\nА Красная Шапочка пошла по самой длинной дороге. Шла она не
# ...

# %%
count_sentence

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')

# %%
nltk.tokenize.sent_tokenize(Text,language='russian')

# %%
count_sentence[0]=8
np.append(count_sentence, 0, axis=None)

# %%
string = string.strip() # удаление пробелов

# %%
Text_clr_paragraph = Text.replace('\n',' ')
Text_clr_paragraph

# %%
symbols = ['—', '\n', ',', '!', '.', ':', ';', '?']
filtr = Text
for smb in symbols:
    filtr = filtr.replace(smb,' ')
filtr = filtr.replace('-','')
filtr = re.sub('\s+', ' ', filtr)
filtr = filtr.lower()
len(filtr.split())

# %%
filtr = Text
#filtr = filtr.replace('\n','.')
filtr = filtr.replace('—',' ')
filtr = re.sub('\s+', ' ', filtr)
senteses = pd.Series([])
count = -1
for snt in re.split('\. |! |\? ',filtr): # Количество предложений
    if snt[0].isupper():
        count += 1
        senteses[count] = snt
    else:
        senteses[count] += snt
print(senteses)

# %%
s = pd.Series(['Бабушка, почему у вас такие большие зубы','Услышали они шум, вбежали в домик и убили Волка'])

# %%
s.keys()

# %%
s = s.drop(s.index[3])
s

# %%
from statistics import geometric_mean

# %%
statistics.harmonic_mean
