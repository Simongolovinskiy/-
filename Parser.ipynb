# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
dir = os.getcwd()
# dir

# %%
FileDB = open(dir+'\\Data\\'+ 'korpus\\'+'korpus.csv',mode = 'r',encoding = 'utf-8') #encoding = 'cp1251' encoding = 'cp1251'
FileDB
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Likholob\\OneDrive\\Project\\TalesPW\\Data\\korpus\\korpus.csv' mode='r' encoding='utf-8'>

# %%
replase_word = pd.read_csv(FileDB, delimiter=',', encoding='utf-8')

# %%
replase_word
# Out:
#          title        file name   views  positive votes  negative votes  \
# 0  Живая шляпа  живая шляпа.txt  382700           15627             969
#
#    rating         author                                               url  \
# 0     4.8  Николай Носов  https://nukadeti.ru/skazki/nosov_zhivaya_shlyapa
#
#                     web           dir        date    1   2    3    4     5
# 0  https://nukadeti.ru/  Data\3yo\txt  09.04.2021  189  37  111  343  6402
